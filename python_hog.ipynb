# %% [markdown]
# ## Import required library

# %%
from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.feature import hog
from skimage import exposure
import matplotlib.pyplot as plt
# %matplotlib inline

img = imread("data/puppy.jpg")
imshow(img)
print(img.shape)
# Out:
# D:\anaconda3\envs\vision\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# (638, 640, 3)

# %% [markdown]
# ## Pre-process image

# %%
resized_img = resize(img, (128, 64))
imshow(resized_img)
print(resized_img.shape)
# Out:
# (128, 64, 3)

# %% [markdown]
# ## Calculate HOG

# %%
fd, hog_image = hog(resized_img, orientations=9, pixels_per_cell=(8, 8), cells_per_block=(2, 2), visualize=True, multichannel=True)
imshow(hog_image)
# Out:
# D:\anaconda3\envs\vision\lib\site-packages\scikit_image-0.18.3-py3.7-win-amd64.egg\skimage\io\_plugins\matplotlib_plugin.py:150: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)
